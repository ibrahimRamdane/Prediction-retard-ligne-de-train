# %%
from tools.tools_database import *

Dataset = read_data('./Data/TGV.csv')

# %%
map_ = display_network(Dataset)

map_
# Out:
# /home/agitated_curran/workdir/Machine Learning/My_projects/prediction-de-retards-tgv-td3-groupe-1/tools/tools_database.py:78: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if len(dataset[dataset['gare_depart']==s[i]][dataset['gare_arrivee']==s[j]]) or  len(dataset[dataset['gare_depart']==s[j]][dataset['gare_arrivee']==s[i]]):
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fead68f798352547e9ac642f0075b83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fead68f798352547e9ac642f0075b83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fead68f798352547e9ac642f0075b83 = L.map(
#                 &quot;map_3fead68f798352547e9ac642f0075b83&quot;,
#                 {
#                     center: [46.603354, 1.888334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8cc459da1e2ac5226c95d92f44113c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3fead68f798352547e9ac642f0075b83);
#
#
#             var marker_beb84b4892b32dd1f6ab18b6e575f238 = L.marker(
#                 [44.8252, -0.5467],
#                 {}
#             ).addTo(map_3fead68f798352547e9ac642f0075b83);
#
#
#         var popup_e69bee43763f91a2df9072b82675c7e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e8fc4870911d671c9021c5611c76a20 = $(`&lt;div id=&quot;html_0e8fc4870911d671c9021c5611c76a20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BORDEAUX ST JEAN&lt;/div&gt;`)[0];
#                 popup_e69bee43763f91a2df9072b82675c7e2.setContent(html_0e8fc4870911d671c9021c5611c76a20);
#
#
#
#         marker_beb84b4892b32dd1f6ab18b6e575f238.bindPopup(popup_e69bee43763f91a2df9072b82675c7e2)
#         ;
#
#
#
#
#             var marker_859bb7897c1cad91f6b98ac6409a16e0 = L.marker(
#                 [46.1555, -1.1516],
#                 {}
#             ).addTo(map_3fead68f798352547e9ac642f0075b83);
#
#
#         var popup_30c64db25a95d7abc419a87c4eae13ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2cea574e1ff548d1aedf5b85da273b7 = $(`&lt;div id=&quot;html_b2cea574e1ff548d1aedf5b85da273b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LA ROCHELLE VILLE&lt;/div&gt;`)[0];
#                 popup_30c64db25a95d7abc419a87c4eae13ec.setContent(html_b2cea574e1ff548d1aedf5b85da273b7);
#
#
#
#         marker_859bb7897c1cad91f6b98ac6409a16e0.bindPopup(popup_30c64db25a95d7abc419a87c4eae13ec)
#         ;
#
#
#
#
#             var marker_cd438a224fdc94afd17451a5efb1d2fe = L.marker(
#                 [48.8406, 2.32],
#                 {}
#             ).addTo(map_3fead68f798352547e9ac642f0075b83);
#
#
#         var popup_1571deb621cf76bf4fe95a0e08ac543f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5900ec34c8ed9fa1871724fe96f28536 = $(`&lt;div id=&quot;html_5900ec34c8ed9fa1871724fe96f28536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PARIS MONTPARNASSE&lt;/div&gt;`)[0];
#                 popup_1571deb621cf76bf4fe95a0e08ac543f.setContent(html_5900ec34c8ed9fa1871724fe96f28536);
#
#
#
#         marker_cd438a224fdc94afd17451a5efb1d2fe.bindPopup(popup_1571deb621cf76bf4fe95a0e08ac543f)
#         ;
#
#
#
#
#             var marker_79f7a2c430cc4c9723e73fbdfebc1207 = L.marker(
#                 [47.9946, -4.0984],
#                 {}
#             ).addTo(map_3fead68f798352547e9ac642f0075b83);
#
#
#         var popup_347ce041adac3604de454c9164735d2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_455f5c7b21c244a2678d64ce296b43bc = $(`&lt;div id=&quot;html_455f5c7b21c244a2678d64ce296b43bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;QUIMPER&lt;/div&gt;`)[0];
#                 popup_347ce041adac3604de454c9164735d2f.setContent(html_455f5c7b21c244a2678d64ce296b43bc);
#
#
#
#         marker_79f7a2c430cc4c9723e73fbdfebc1207.bindPopup(popup_347ce041adac3604de454c9164735d2f)
#         ;
#
#
#
#
#             var marker_352d307a5c091b2662ea7a0297d6f628 = L.marker(
#                 [48.1069, -1.6791],
#                 {}
#             ).addTo(map_3fead68f798352547e9ac642f0075b83);
#
#
#         var popup_c70b015f5a388efe6b17b45f49168c0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f3c3484f55d4a6415be49b56fedef26 = $(`&lt;div id=&quot;html_8f3c3484f55d4a6415be49b56fedef26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RENNES&lt;/div&gt;`)[0];
#                 popup_c70b015f5a388efe6b17b45f49168c0a.setContent(html_8f3c3484f55d4a6415be49b56fedef26);
#
#
#
#         marker_352d307a5c091b2662ea7a0297d6f628.bindPopup(popup_c70b015f5a388efe6b17b45f49168c0a)
#         ;
#
#
#
#
#             var marker_7597909b3c0e255e765ec8b9295a6d35 = L.marker(
#                 [47.3906, 0.7234],
#                 {}
#             ).addTo(map_3fea

# %%
map_ = display_map_delays(Dataset, column='delay')

map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c792ec9ef0c04dccf8c85c129f02a27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c792ec9ef0c04dccf8c85c129f02a27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c792ec9ef0c04dccf8c85c129f02a27 = L.map(
#                 &quot;map_0c792ec9ef0c04dccf8c85c129f02a27&quot;,
#                 {
#                     center: [46.603354, 1.888334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f6713db55201fdcb6695938a0152e12 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0c792ec9ef0c04dccf8c85c129f02a27);
#
#
#             var circle_1cba3d8b91977cfcee0198434cc07841 = L.circle(
#                 [44.8252, -0.5467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15259.001241707369, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0c792ec9ef0c04dccf8c85c129f02a27);
#
#
#             var circle_f79d5a76a25ebfbef14f0abbdd640199 = L.circle(
#                 [46.1555, -1.1516],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17357.946915675973, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0c792ec9ef0c04dccf8c85c129f02a27);
#
#
#             var circle_0846784ffc6423aef4fbf3fcbf964260 = L.circle(
#                 [48.8406, 2.32],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 24133.01073440704, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0c792ec9ef0c04dccf8c85c129f02a27);
#
#
#             var circle_e8afd44730525c7bdeac072cdbad371d = L.circle(
#                 [47.9946, -4.0984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15164.582382878025, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0c792ec9ef0c04dccf8c85c129f02a27);
#
#
#             var circle_92fa2e78ec0f67a5970755a4f8199fbb = L.circle(
#                 [48.1069, -1.6791],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23051.04247320044, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0c792ec9ef0c04dccf8c85c129f02a27);
#
#
#             var circle_d01574fb1ca42c5cd862f17da9b2a268 = L.circle(
#                 [47.3906, 0.7234],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 39149.713466064466, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0c792ec9ef0c04dccf8c85c129f02a27);
#
#
#             var circle_df86578c282be413b9c87ab1f5e6d0e2 = L.circle(
#                 [47.3941, 0.6871],

# %%
map_ = display_map_delays(Dataset, column='nb_train_retard_arrivee')

map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb1073e419855d251d3f8f3391e638e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb1073e419855d251d3f8f3391e638e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb1073e419855d251d3f8f3391e638e9 = L.map(
#                 &quot;map_fb1073e419855d251d3f8f3391e638e9&quot;,
#                 {
#                     center: [46.603354, 1.888334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2757bccbfd7d8f2bf57cc7d06a44a43 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb1073e419855d251d3f8f3391e638e9);
#
#
#             var circle_008251d374f0671c45e6e81a139628bd = L.circle(
#                 [44.8252, -0.5467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 46052.22286650176, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fb1073e419855d251d3f8f3391e638e9);
#
#
#             var circle_520a03afd01293f2fee70c8bf406c9fe = L.circle(
#                 [46.1555, -1.1516],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18637.455322528796, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fb1073e419855d251d3f8f3391e638e9);
#
#
#             var circle_7d637dd00067b517109ed479a5aef174 = L.circle(
#                 [48.8406, 2.32],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 63271.49010003972, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fb1073e419855d251d3f8f3391e638e9);
#
#
#             var circle_a2779bad4586e526d18d12ba07df326b = L.circle(
#                 [47.9946, -4.0984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 24098.035136821803, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fb1073e419855d251d3f8f3391e638e9);
#
#
#             var circle_d091158ff9f0f8f0aa1312fdda3fa50e = L.circle(
#                 [48.1069, -1.6791],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 45071.6257871745, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fb1073e419855d251d3f8f3391e638e9);
#
#
#             var circle_bce52daf844589c5df8c58b28e09eccf = L.circle(
#                 [47.3906, 0.7234],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 63056.79003006865, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_fb1073e419855d251d3f8f3391e638e9);
#
#
#             var circle_411e210f6f3a4f83e662df8dd5bf92ff = L.circle(
#                 [47.3941, 0.6871],

# %%
A = np.unique(Dataset['gare_depart'])

station_coordinates = load_coords()
Net = build_network(station_coordinates, Dataset, A)

for i in range(len(A)) :
    for j in range(len(A)) :
        if i!=j and Net[i, j] :
            box_plot_months(Dataset, A[i], A[j], 'duree_moyenne')
            break
    break
# Out:
# /home/agitated_curran/workdir/Machine Learning/My_projects/prediction-de-retards-tgv-td3-groupe-1/tools/tools_database.py:78: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if len(dataset[dataset['gare_depart']==s[i]][dataset['gare_arrivee']==s[j]]) or  len(dataset[dataset['gare_depart']==s[j]][dataset['gare_arrivee']==s[i]]):

# %%
Dataset['difference'] = Dataset['retard_moyen_arrivee'] - Dataset['retard_moyen_depart']


for i in range(2, len(A)) :
    for j in range(len(A)) :
        if i!=j and Net[i, j] :
            box_plot_months(Dataset, A[i], A[j], 'difference')
            
    break

# %%
Dataset.columns
# Out:
# Index(['date', 'service', 'gare_depart', 'gare_arrivee', 'duree_moyenne',
#        'nb_train_prevu', 'nb_annulation', 'commentaire_annulation',
#        'nb_train_depart_retard', 'retard_moyen_depart',
#        'retard_moyen_tous_trains_depart', 'commentaire_retards_depart',
#        'nb_train_retard_arrivee', 'retard_moyen_arrivee',
#        'retard_moyen_tous_trains_arrivee', 'commentaires_retard_arrivee',
#        'nb_train_retard_sup_15', 'retard_moyen_trains_retard_sup15',
#        'nb_train_retard_sup_30', 'nb_train_retard_sup_60',
#        'prct_cause_externe', 'prct_cause_infra', 'prct_cause_gestion_trafic',
#        'prct_cause_materiel_roulant', 'prct_cause_gestion_gare',
#        'prct_cause_prise_en_charge_voyageurs', 'difference'],
#       dtype='object')

# %%
Cols = ['duree_moyenne', 'nb_train_prevu', 'nb_annulation', 'nb_train_depart_retard', 'retard_moyen_depart',
       'retard_moyen_tous_trains_depart', 'nb_train_retard_arrivee', 'retard_moyen_arrivee',
       'retard_moyen_tous_trains_arrivee', 'prct_cause_externe', 'prct_cause_infra', 'prct_cause_gestion_trafic',
       'prct_cause_materiel_roulant', 'prct_cause_gestion_gare']

histograms(Dataset, Cols)

# %%
train_set = Dataset[Dataset['date'].dt.year != 2023]
test_set = Dataset[Dataset['date'].dt.year == 2023]

print(len(train_set), len(test_set))
# Out:
# 7331 719

# %%
print(len(Dataset))
Dataset = remove_outliers(Dataset, 3)
print(len(Dataset))
# Out:
# 8154
# 8050

# %%
Dataset['difference'] = Dataset['retard_moyen_arrivee'] - Dataset['retard_moyen_depart']


for i in range(2, len(A)) :
    for j in range(len(A)) :
        if i!=j and Net[i, j] :
            box_plot_months(Dataset, A[i], A[j], 'difference')
